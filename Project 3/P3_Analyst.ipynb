# %%
import selenium
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.common.by import By
import time
import random
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
Predictions = pd.read_csv('/Users/ashleyrabanales/OneDrive - Georgia State University/Data Management in Analytics/Crucial_Data_Crew.SQL/Project 3/datasets/predictions.csv')

# %%
ID1 = Predictions['analyst'].drop_duplicates()

# %%
len(ID1)
# Out:
# 8798

# %%
IDD = ID1.loc[0:2]

Analyst = []
Analyst
IDD
# Out:
# 0    analyst_9404487
# 1    analyst_6216740
# 2     analyst_530056
# Name: analyst, dtype: object

# %%
path = r'/Users/yanchenglai/Desktop/chromedriver' #f path 
driver_service = Service(executable_path=path)
driver = webdriver.Chrome(service=driver_service)
url = 'https://www.estimize.com/'
time.sleep(random.uniform(5,10))
options = webdriver.ChromeOptions()
options.add_argument('--headless')
options.add_argument('--no-sandbox')
options.add_argument('--disable-dev-shm-usage')
counter = 0
# open it, go to a website, and get results


for ID in ID1[310]:
    counter = counter + 1
    time.sleep(random.uniform(2,3))
    driver.get(f"{url}/users{ID}")
    time.sleep(random.uniform(2,3))
# row to append to final list/dataframe
try:
    login = driver.find_element('xpath','//*[@id="top-navigation"]/div[1]/ul/li[8]/a')
    login.click()
    time.sleep(random.uniform(5,10))
    # list username and password as variables
    username = 'cbrown180@student.gsu.edu'
    password = '123456'
    # find email field in HTML and send username to field -- sleep 2 seconds
    email_field = driver.find_element('name','user[login]')
    email_field.send_keys(username)
    time.sleep(random.uniform(2,6))
    # find the password field and input password and submit
    password_field = driver.find_element('name','user[password]')
    password_field.send_keys(password)
    password_field.submit()
    time.sleep(random.uniform(3,9))
except NoSuchElementException:
    pass

for ID in IDD:
    wd.get(f"{url}/users/{ID}")
    row = {}
    # create variable to assign ticker to the row 
    row['AnalystID'] = ID
    # grab analyst id... not just the name grab the data user to use in url for final scraper
    name = wd.find_element('xpath',f'//*[@id="users_show"]/div[4]/div[1]/div[1]/div[1]/div/h1/a').text
    row['Name'] = name
    time.sleep(random.uniform(2,6))
    role = wd.find_element('xpath', f'//*[@id="users_show"]/div[4]/div[1]/div[1]/div[1]/div/ul').text
    row['Role'] = role
    time.sleep(random.uniform(2,6))
    join_date = wd.find_element('xpath', f'//*[@id="users_show"]/div[4]/div[1]/div[1]/div[1]/div/div[2]/div[2]').text
    row['Join Date'] = join_date
    time.sleep(random.uniform(2,6))
    cs = wd.find_element('xpath', f'//*[@id="confidence-wrap"]/div/div[2]').text
    row['Analyst Confidence Score'] = cs
    time.sleep(random.uniform(2,6))
    Err = wd.find_element('xpath',f'//*[@id="profile-tab-wrap"]/div[1]/div[1]/div[3]').text
    row['Error rate'] = Err
    time.sleep(random.uniform(2,6))
    Accu = wd.find_element('xpath',f'//*[@id="profile-tab-wrap"]/div[1]/div[2]/div[2]').text
    row['Accuracy Percentile'] = Accu
    time.sleep(random.uniform(3,6))
    Points = wd.find_element('xpath',f'//*[@id="profile-tab-wrap"]/div[2]/div[1]/div[3]').text
    row['Points'] = Points
    time.sleep(random.uniform(2,6))
    PointsE = wd.find_element('xpath',f'//*[@id="profile-tab-wrap"]/div[2]/div[2]/div[2]').text
    row['Points/Estimate'] = PointsE
    time.sleep(random.uniform(2,6))
    Stocks = wd.find_element('xpath',f'//*[@id="profile-tab-wrap"]/div[3]/div[1]/div[3]').text
    row['Stocks'] = Stocks
    time.sleep(random.uniform(2,6))
    Pending = wd.find_element('xpath',f'//*[@id="profile-tab-wrap"]/div[3]/div[2]/div[3]').text
    row['Pending'] = Pending
    time.sleep(random.uniform(2,6))
    if row not in Analyst:
                Analyst.append(row)
                print(counter)
# Out:
# ---------------------------------------------------------------------------
# NoSuchWindowException                     Traceback (most recent call last)
# /var/folders/4t/j0tpqxs11zz8x88ccnwr34rc0000gn/T/ipykernel_39209/3542241484.py in <module>
#      17     counter = counter + 1
#      18     time.sleep(random.uniform(2,3))
# ---> 19     driver.get(f"{url}/users{ID}")
#      20     time.sleep(random.uniform(2,3))
#      21 # row to append to final list/dataframe
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py in get(self, url)
#     453         Loads a web page in the current browser session.
#     454         """
# --> 455         self.execute(Command.GET, {"url": url})
#     456
#     457     @property
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
# ...

# %%
path = r'/Users/yanchenglai/Desktop/chromedriver' #f path 
driver_service = Service(executable_path=path)
driver = webdriver.Chrome(service=driver_service)
url = 'https://www.estimize.com/'
time.sleep(random.uniform(5,10))
options = webdriver.ChromeOptions()
options.add_argument('--headless')
options.add_argument('--no-sandbox')
options.add_argument('--disable-dev-shm-usage')
# open it, go to a website, and get results
wd = webdriver.Chrome(options=options)
driver.get(f"{url}/users/analyst_5646744")

# row to append to final list/dataframe
try:
    login = driver.find_element('xpath','//*[@id="top-navigation"]/div[1]/ul/li[8]/a')
    login.click()
    time.sleep(random.uniform(5,10))
    # list username and password as variables
    username = 'cbrown180@student.gsu.edu'
    password = '123456'
    # find email field in HTML and send username to field -- sleep 2 seconds
    email_field = driver.find_element('name','user[login]')
    email_field.send_keys(username)
    time.sleep(random.uniform(2,6))
    # find the password field and input password and submit
    password_field = driver.find_element('name','user[password]')
    password_field.send_keys(password)
    password_field.submit()
    time.sleep(random.uniform(3,9))
except NoSuchElementException:
    pass
wd.get(f"{url}/users/analyst_9404487")

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By

options = webdriver.ChromeOptions()
options.add_argument('--headless')
options.add_argument('--no-sandbox')
options.add_argument('--disable-dev-shm-usage')
# open it, go to a website, and get results
wd = webdriver.Chrome(options=options)
wd.get("https://www.glassdoor.com/member/home/index.htm")
print(wd.page_source)  # results
# Out:
# <html lang="en" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraph.org/schema/" class="flex canvas svgfilters cssfilters no-touchevents"><head prefix="og: http://ogp.me/ns# fb: http://ogp.me/ns/fb# glassdoor: http://ogp.me/ns/fb/glassdoor#"><!-- because the getter clears the value --><script src="https://apis.google.com/_/scs/abc-static/_/js/k=gapi.lb.en.geaHZXF2-fw.O/m=auth2/exm=client/rt=j/sv=1/d=1/ed=1/rs=AHpOoo9yYF5eCIYPx4UH9gpJptM2Q_GGxQ/cb=gapi.loaded_1?le=scs" async=""></script><script src="https://apis.google.com/_/scs/abc-static/_/js/k=gapi.lb.en.geaHZXF2-fw.O/m=client/rt=j/sv=1/d=1/ed=1/rs=AHpOoo9yYF5eCIYPx4UH9gpJptM2Q_GGxQ/cb=gapi.loaded_0?le=scs" async=""></script><script type="text/javascript" integrity="sha384-VuGgAcmMrGHihvjXxxBVMIqoDFXc8/PO9q/08kCgq4Wn1iPnSmUbI3xhXaFozVFv" crossorigin="anonymous" async="" src="https://cdn.amplitude.com/libs/amplitude-8.18.1-min.gz.js"></script><script src="https://connect.facebook.net/en_US/sdk.js?hash=bc149b3b22a
# ...
